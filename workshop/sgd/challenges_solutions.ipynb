# %%
from operator import itemgetter
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema import StrOutputParser
from langchain.schema import BaseOutputParser
import json
import pandas as pd

from dotenv import load_dotenv
load_dotenv()

model = ChatOpenAI(
    # model='gpt-3.5-turbo-16k-0613',
    model='gpt-3.5-turbo-1106',
    temperature = 0.1
)

# %%
prompt1 = ChatPromptTemplate.from_template("""
from the given social media posts from people in the given province. please analize base on un sdg goals. return output only in json format

### province
ปทุมธานี

### social media posts
ปทุมธานีรถติดมาก
อุบัติเหตุหน้ามธ.รถติดยาว
มธ.เดินทางไปอย่างไรจากสระบุรี

### instruction
1. identify user group that has posted on social media
2. as a psychologist, please analyze did the users have posted those massageas 
3. classify sentiment of the post whether positive, neutal or negative. If negative following step 4, 5 and 6 otherwise go to step 5 and 6.
4. identify a concern or an issue
5. identify a wish of the users
6. return output in json format that contain

### example province
{example_province}

### example social media posts
{example_social_posts}

### example output format
{example_output}

### province
{province}

### social media posts
{social_posts}

### output format
""")

# %%
class IndicatorOutputParser(BaseOutputParser):
    """Parse the output of an LLM call to a comma-separated list."""


    def parse(self, social_analysis: dict):
        obj_social_analysis=json.loads(social_analysis)
        targets=[i.split(' ')[0][4:] for i in obj_social_analysis['relevance_sdg_target']]
        df2=pd.read_csv('sdg.csv')
        df2=df2.query("target == @targets")
        text_indicators=[]
        for idx,i in df2[['indicator','indicator_description']].iterrows():
            text_indicators.append({'indicator':i['indicator'], 'indicator_description':i['indicator_description']}  )
        obj_social_analysis['relevance_sdg_indicators']=text_indicators
        return obj_social_analysis

# %%
chain1 = prompt1 | model |  StrOutputParser() | IndicatorOutputParser()

# %%
prompt2 = ChatPromptTemplate.from_template("""
Form social post anylysis and the given sdg indicators, please anaylize challenges 
then select indicator and provide posible solutions 
that can fulfil the gap between user wishes and the indicator in the style of Bjorn Lomborg. 
return output only in json format

### example social post anylysis
{example_chain2_social_analysis}

### example output json format
{example_chain2_output}

### social post anylysis
{obj_social_analysis}

### output json format
""")

# %%
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate
from langchain.pydantic_v1 import BaseModel, Field, validator
from typing import List
from langchain.output_parsers import OutputFixingParser

class Challenge(BaseModel):
    challenge_description: str = Field(description="a gap between the people wishes and the current situation")
    challenge_topic: str = Field(description="short name of the challenge")
    indicators: List[str] = Field(description="list of relevance SDG indicators")
    solutions: List[str] = Field(description="list of solutions for the challenges")


actor_query = "Extract information from the social post analysis"

parser = PydanticOutputParser(pydantic_object=Challenge)

prompt = PromptTemplate(
    template="Answer the query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

new_parser = OutputFixingParser.from_llm(parser=parser, llm=ChatOpenAI())

chain2 = (
    {
        "obj_social_analysis": chain1, 
        "example_chain2_social_analysis": itemgetter("example_chain2_social_analysis"),
        "example_chain2_output": itemgetter("example_chain2_output")
    }
    | prompt2
    | model
    | StrOutputParser()
    |new_parser
)

# %%
def get_challenge_solutions(location="ประเทศไทย",posts=["นักเรียนจบแล้วมีทักษะไม่พร้อมสำหรับการทำงาน",]):
    with open('template.json', 'r') as openfile:
        template = json.load(openfile)
    template['province']=location
    template['social_posts']=posts
    
    c2=chain2.invoke(template)
    d={}
    d['challenge_topic']=c2.challenge_topic
    d['challenge_description']=c2.challenge_description
    d['indicators']=c2.indicators
    d['solutions']=c2.solutions
    return d
get_challenge_solutions()
# Out:
# {'challenge_topic': 'Job Readiness and Skills Development',
#  'challenge_description': 'Recent graduates expressing concerns about their readiness for the workforce, indicating a need for improved job training and preparation programs.',
#  'indicators': ["SDG_Indicator_4.4.1: Proportion of youth and adults with information and communications technology (ICT) skills by type of skill aligns with the users' wish for improved job training and relevant skills for employment."],
#  'solutions': ['Enhance vocational and technical training programs to equip graduates with the necessary skills for employment, focusing on ICT skills and other relevant technical abilities demanded by the job market.',
#   'Establish partnerships between educational institutions and industries to provide practical training and internships, bridging the gap between theoretical knowledge and practical workplace skills.',
#   'Introduce career counseling and mentorship programs to guide graduates in identifying their strengths, interests, and career pathways, thus enhancing their job readiness and confidence in entering the workforce.',
#   'Promote entrepreneurship and innovation through workshops, seminars, and networking events, encouraging graduates to explore entrepreneurial opportunities and contribute to economic growth and job creation in their communities.']}

# %%
df=pd.read_csv('posts.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15195 entries, 0 to 15194
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        15195 non-null  int64
#  1   Topic        15195 non-null  int64
#  2   Name         15195 non-null  object
#  3   Document     15195 non-null  object
#  4   Probability  15195 non-null  float64
#  5   content      15195 non-null  object
#  6   province     15195 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 831.1+ KB
#    index  Topic                                               Name  \
# 0      1      0  0_#รายงานฝนฟ้าอากาศ_ทางไหนฝนตกกันบ้างข้าว_กำลั...
# 1      2      0  0_#รายงานฝนฟ้าอากาศ_ทางไหนฝนตกกันบ้างข้าว_กำลั...
# 2      3      0  0_#รายงานฝนฟ้าอากาศ_ทางไหนฝนตกกันบ้างข้าว_กำลั...
# 3      4      0  0_#รายงานฝนฟ้าอากาศ_ทางไหนฝนตกกันบ้างข้าว_กำลั...
# 4      5      0  0_#รายงานฝนฟ้าอากาศ_ทางไหนฝนตกกันบ้างข้าว_กำลั...
#
#                                             Document  Probability  \
# 0          ฝนตก … นอกหน้าต่าง #ฤดูฝน #วันฝนพรำ #ฝนตก     1.000000
# 1  ฝนกำลังมาจาก อ.วังทอง ถ้าไม่แวะไหนก่อน ก็กำลัง...     0.950048
# 2                               ในตัวเมืองฝนตกนะครับ     1.000000
# 3  สวัสดีวันพฤหัสบดี 12 ตค 2566 05.00 น. \n🐓🐓🐓☕😁\...     1.000000
# 4                  ไหนบอกเข้าหนาว\nฝนโปรยแล้วในเมือง     1.000000
#
#                                              content    province
# 0          ฝนตก … นอกหน้าต่าง #ฤดูฝน #วันฝนพรำ #ฝนตก      พิจิตร
# 1  ฝนกำลังมาจาก อ.วังทอง ถ้าไม่แวะไหนก่อน ก็กำลัง...    พิษณุโลก
# 2                               ในตัวเมืองฝนตกนะครับ    พิษณุโลก
# 3  สวัสดีวันพฤหัสบดี 12 ตค 2566 05.00 น. \n🐓🐓🐓☕😁\...  ฉะเชิงเทรา
# 4                  ไหนบอกเข้าหนาว\nฝนโปรยแล้วในเมือง    พิษณุโลก

# %%
df2=df[['content','province']]

# %%
df3=df2.groupby(['province','content']).agg({'province':['count']})

# %%
df3.reset_index()
# Out:
#         province                                            content province
#                                                                        count
# 0         global  "โลตัส" พลิกโฉมธุรกิจแบบ Transformational Grow...        1
# 1         global                                         #สีดาโคราช        2
# 2         global  .\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...        5
# 3         global  1.ควรไปจังหวัดไหนก่อน\n2.มีเวลา 7 วันครับ\n\nร...        3
# 4         global  19 ต.ค. 2565  -  18:25 น.\n\nน้ำตาท่วมวัด! เผา...        1
# ...          ...                                                ...      ...
# 9801  แม่ฮ่องสอน  📣ประกาศเขตพื้นที่❗️ห้ามดื่ม เครื่องดื่มแอลกอฮอ...        1
# 9802  แม่ฮ่องสอน  🙏🏼พลังแห่งศรัทธาร่วมบูรณะ\n"สะพานซูตองเป้" สะพ...        1
# 9803  แม่ฮ่องสอน  🚨สภ.ขุนยวม\nอำนวยการโดย\nพ.ต.อ.พิษณุ สมนึก\n  ...        1
# 9804  แม่ฮ่องสอน  🟡 l อำเภอสบเมย นำสิ่งของบรรเทาทุกข์ มอบให้ราษฎ...        1
# 9805  แม่ฮ่องสอน  🟡 l อำเภอสบเมย ประกอบพิธีวางพวงมาลา เนื่องในวั...        1
#
# [9806 rows x 3 columns]

# %%
df3.to_excel('posts2.xlsx',engine='xlsxwriter')
# Out:
# /home/wasit/miniconda3/envs/dsmde/lib/python3.10/site-packages/xlsxwriter/worksheet.py:1252: UserWarning: Ignoring URL 'https://www.thaipbs.or.th/news/content/321541
#
# จากกรณีที่ไทยพีบีเอสได้รายงานข่าวในข่าวภาคค่ำและในเว็บไซต์ข่าวไทยพีบีเอส เมื่อวันที่ 14 พ.ย.ที่ผ่านมา เรื่องเมนูที่จะใช้ในงานเลี้ยงผู้นำเขตเศรษฐกิจภูมิภาคเอเชีย-แปซิฟิก (เอเปค) โดยอ้างคำสัมภาษณ์ของผู้ประกอบการในพื้นที่ อ.ตากใบ จ.นราธิวาส ว่า ปลากุเลาเค็มตากใบที่จะใช้ในงานเลี้ยงไม่ใช่ปลากุเลาจากตากใบ ต่อมา น.ส.รัชดา ธนาดิเรก รองโฆษกรัฐบาล ชี้แจงว่า ปลากุเลาที่นำมาใช้ปรุงอาหารได้สั่งซื้อมาจากร้านป้าอ้วน ซึ่งเป็นปลากุเลาเค็มตากใบจริง
# ไทยพีบีเอสขอชี้แจง ดังต่อไปนี้
#
# 1. ผู้สื่อข่าวลงพื้นที่ อ.ตากใบ ด้วยความตั้งใจที่จะนำเสนอความภาคภูมิใจของชาวตากใบที่ผลิตภัณฑ์ในพื้นที่ได้รับการยอมรับในระดับสากล แต่ได้รับข้อมูลจากผู้ประกอบการหลายร้านว่า ไม่มีการสั่งซื้อปลากุเลาจากร้านในพื้นที่ รวมถึงในไลน์กลุ่มวิสาหกิจชุมชนปลากุเลาตากใบ ก็มีการสอบถามกันว่ารัฐบาลซื้อปลาจากร้านไหน แต่ไม่มีใครยืนยันว่าได้รับการสั่งซื้อ
#
# ก่อนหน้านี้รัฐบาลประชาสัมพันธ์ว่า ได้นำปลากุเลาเค็มตากใบมาใช้ปรุงอาหารในงานเลี้ยงผู้นำเอเปค แต่มีหน่วยงานของรัฐนำภาพวิสาหกิจชุมชนปลากุเลาเค็มในอีกจังหวัดหนึ่ง ไปประกอบข้อมูลปลากุเลาเค็มจากตากใบ จึงทำให้ผู้ประกอบการที่ตากใบเห็นว่า เป็นข้อมูลที่คลาดเคลื่อนและอาจทำให้เกิดผลกระทบต่อภาพลักษณ์ของผลิตภัณฑ์ของชุมชน
#
# 2. ผู้สื่อข่าวไทยพีบีเอสสัมภาษณ์ผู้ประกอบการที่ตากใบรายใหญ่หลายราย ซึ่งให้ข้อมูลตรงกันว่า รู้สึกผิดหวังที่ไม่มีการสั่งซื้อปลากุเลาเค็มตากใบ และยังใช้ภาพของวิสาหกิจชุมชนที่อื่นประกอบการประชาสัมพันธ์อีกด้วย
#
# 3. หลังการนำเสนอในข่าวภาคค่ำของไทยพีบีเอสและเว็บไซต์ข่าวไทยพีบีเอส ต่อมาได้มีคำชี้แจงจาก น.ส.รัชดา ธนาดิเรก รองโฆษกรัฐบาล ยืนยันว่า ได้สั่งซื้อปลากุเลาเค็มตากใบจากร้านป้าอ้วน ไทยพีบีเอสจึงได้นำเสนอข้อมูลนี้ในข่าวภาคดึก และเว็บไซต์ข่าวไทยพีบีเอส ต่อมาร้านป้าอ้วนชี้แจงผ่านเพจเฟซบุ๊ก ว่า “ก่อนหน้านี้มีเจ้าหน้าที่มาซื้อปลากุเลาเค็มไปจำนวน 1 ตัว เพื่อนำไปชิม กระทั่งมีการสั่งซื้อผ่านออนไลน์ เนื่องจากมีการซื้อวันละหลายหมื่นบาท ในช่วง 2-3 วัน ที่ผ่านมา หลังจากมีกระแสข่าวเอเปค ทำให้ทางร้านไม่ทันได้ตรวจสอบ ซึ่งยืนยันว่าหน่วยงานภาครัฐ โดยตัวแทนได้สั่งผ่านระบบออนไลน์ไป จึงเกิดข้อผิดพลาดกันในกลุ่มผู้ค้าปลากุเลาเค็ม ตากใบ”
#
# 4. ไทยพีบีเอสขอยืนยันว่าไม่ได้มีเจตนาที่จะสร้างความเข้าใจผิดในกรณีดังกล่าว การนำเสนอข่าวนี้เป็นการสะท้อนความรู้สึกและความเห็นของชาวบ้านในพื้นที่ที่กังวลต่อภาพลักษณ์ของผลิตภัณฑ์ที่พวกเขาภาคภูมิใจ
#
# 5. ไทยพีบีเอส ยอมรับว่า การนำเสนอข่าวดังกล่าวขาดความรอบด้าน โดยมิได้ตรวจสอบข้อมูลจากหน่วยงานที่เกี่ยวข้อง ซึ่งเป็นหลักการพื้นฐานของสื่อมวลชน อย่างไรก็ตาม เมื่อมีการชี้แจงจากผู้ที่เกี่ยวข้อง ไทยพีบีเอสก็นำเสนอข้อมูลที่ได้รับในเวลาต่อมา
#
# 6. กองบรรณาธิการไทยพีบีเอสขออภัยในความบกพร่อง ที่อาจจะทำให้เกิดความเข้าใจผิดในเรื่องดังกล่าว และได้ตั้งคณะกรรมการตรวจสอบข้อเท็จจริงขึ้น ตามระเบียบขององค์กร เพื่อป้องกันไม่ให้เกิดกรณีเช่นนี้ขึ้นอีกในอนาคต
#
# 7. ไทยพีบีเอสขอยืนยันเจตนารมณ์ในฐานะสื่อสาธารณะในการรายงานข่าวและนำเสนอข้อมูลอย่างถูกต้องรอบด้าน เป็นธรรม และให้ความสำคัญกับการประชุมเอเปค ซึ่งมีความสำคัญต่อประเทศไทยเป็นอย่างยิ่ง เช่นเดียวกับการสะท้อนความรู้สึก ความคิดเห็นของประชาชนทุกระดับ' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn(
# /home/wasit/miniconda3/envs/dsmde/lib/python3.10/site-packages/xlsxwriter/worksheet.py:1252: UserWarning: Ignoring URL 'https://fb.watch/ns4yvMQ7EB/
# ' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn(
# /home/wasit/miniconda3/envs/dsmde/lib/python3.10/site-packages/xlsxwriter/worksheet.py:1252: UserWarning: Ignoring URL 'https://www.khaosod.co.th/around-thailand/news_7544180
#
# %3e
#  บิ๊กไบก์ ซิ่งยกล้อเสียหลักพุ่งเข้าร้านค้า คนขี่ร่า...
#
# บิ๊กไบก์ ซิ่งยกล้อเสียหลักพุ่งเข้าร้านค้า คนขี่ร่างกระเด็น50เมตรเป็นตายเท่ากัน
# ทุกทิศทั่วไทย
#
# 5 มี.ค. 2566-20:31 น.
#
#
# วงจรปิดจับภาพเหตุการณ์ บิ๊กไบก์ ซิ่งยกล้อเสียหลักพุ่งเข้าร้านค้า คนขี่ร่างกระเด็น50เมตรเป็นตายเท่ากัน อาการสาหัส แขนขาหักผิดรูป
# วันที่ 5 มี.ค.2566 ผู้สื่อข่าวได้รับภาพจากกล้องวงจรปิดบริเวณตลาดแม่กลอง เขตเทศบาลเมืองสมุทรสงคราม ที่บันทึกภาพเหตุการณ์นายณัฐพัชร์ อายุ 27 ปี ชาวจังหวัดประจวบคีรีขันธ์ ขับขี่รถจยย.บิ๊กไบก์ คาวาซากิ Z900 ทะเบียน 2กฆ5911 ระยอง อย่างรวดเร็วและมีลักษณะคล้ายยกล้อก่อนจะเสียหลักพุ่งชนเข้ามาในร้านค้าริมถนนประสิทธิ์พัฒนา ตลาดแม่กลอง ทำให้นายณัฐพัชร์ ซึ่งกระเด็นไปไกลกว่า 50 เมตร เข้าไปนิ่งอยู่ภายในร้านขายดอกไม้ ได้รับบาดเจ็บสาหัส
#
#
#
# เจ้าหน้าที่กู้ภัยมูลนิธิสว่างเบญจธรรมสมุทรสงครามเร่งนำตัวส่งโรงพยาบาลสมเด็จพระพุทธเลิศหล้า เหตุเกิดเมื่อเวลา 03.11 น. ที่ผ่านมา ต่อมผู้สื่อข่าวจึงลงพื้นที่ไปที่เกิดเหตุ ยังพบความเสียหายจากอุบัติเหตุที่เกิดขึ้น โดยนายวิโรจน์ อายุ 55 ปี เจ้าของร้านขายดอกไม้ หนึ่งในผู้เสียหายได้ส่งคลิปที่บันทึกภาพเหตุการณ์ที่บันทึกความเสียหายขณะเกิดเหตุ
#
#
# นายวิโรจน์ เล่าว่า ขณะที่เกิดเหตุตนไม่ได้อยู่ที่ร้าน กลับไปนอนอยู่ในบ้าน เมื่อมีเพื่อโทรมาบอกว่าที่ร้านโดนชนจึงออกมาดูก็พบว่าเจ้าหน้าที่กู้ภัยกำลังพาคนเจ็บส่งโรงพยาบาล ที่ร้านได้รับความเสียหายเล้กน้อยพอที่จะนำเหล็กแผงขายดอกไม้มาดัดขายของชั่วคราวไปก่อน โชคดีที่ช่วงเกิดเหตุยังไม่มีพ่อค้าแม่ค้าออกมาขายของบนจุดเกิดเหตุ
#
#
# นายอนุวัฒน์ ภัทรจิตตานันท์ พนักงานฉุกเฉินการแพทย์ มูลนิธิสว่างเบญจธรรมสมุทรสงคราม กล่าวว่า รถบิ๊กไบก์ชนคว่ำได้รับความเสียหายอยู่บริเวณริมฟุตบาทส่วนผู้บาดเจ็บกระเด็นเข้าไปในร้านขายดอกไม้ประมาณ 50 เมตร ไปกระแทกนั่งพิงกับผนังร้านค้า ไม่รู้สึกตัว ขาขวา แขนขวาหักผิดรูป มีภาวะหายใจแบบหิวอากาศเป็นลักษณะการหายใจที่พบได้บ่อยในผู้ป่วยระยะท้าย ที่ใกล้เสียชีวิต
#
#
# ล่าสุดได้รับการแจ้งว่า ผู้ชาดเจ็บอาการยังไม่พ้นขีดอันตราย ยังคงรักษาตัวอยู่ในห้อง ICU โรงพยาบาลสมเด็จพระพุทธเลิศหล้า อย่างไรก็ตามฝากผู้ใช้รถใช้ถนนขอให้ขับรถด้วยความระมัดระวังอย่าประมาทเพราะอาจทำให้เสียชีวิตได้																																	%20%20%20แก้ไขข้อความเมื่อ' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn(
# /home/wasit/miniconda3/envs/dsmde/lib/python3.10/site-packages/xlsxwriter/worksheet.py:1252: UserWarning: Ignoring URL 'https://www.banmuang.co.th/news/region/329781
#
# ที่จังหวัดสุพรรณบุรีเมื่อเวลาประมาณ 15.20 น.วันที่ 21 พฤษภาคม 2566 ร.ต.อ.ฤทธิพงศ์ มะปะเข พนักงานสอบสวน สภ.บางปลาม้า จังหวัดสุพรรณบุรี รับแจ้งเหตุรถเฉี่ยวกันมีไฟไหม้และมีผู้ได้รับบาดเจ็บที่ถนนสาย 340 สุพรรณบุรี - บางบัวทอง หมู่ 5 ตำบลโคกคราม จึงประสานรถน้ำดับเพลิง และสมาคมเณรแก้วกู้ภัยทางหลวงสุพรรณบุรี ไปตรวจสอบ
#
# ที่เกิดเหตุเลยจุดกลับรถหน้าโรงเรียนสูงสุมารผดงวิทย์ประมาณ 200 เมตร พบไฟกำลังลุกไหม้รถจักรยานยนต์บิ๊กไบก์อยู่โคนเสาไฟฟ้าส่องสว่างใกล้ร่องกลางถนน ลุกลามไหม้หญ้ารวมทั้งดอกไม้ริมร่องกลางถนนเจ้าหน้าที่จึงรีบฉีดน้ำควบคุมใช้เวลาประมาณ 10 นาทีเพลิงจึงสงบ และรถจักรยานยนต์บิ๊กไบก์ถูกไฟไหม้ละลายกลายเป็นเศษเหล็ก ห่างกันประมาณ 150 เมตรพบรถบรรทุกพ่วง 18 ล้อยี่ห้อฮีโน่สีขาวทะเบียน 88 – 3946 นครปฐม จอดอยู่ ตรวจสอบที่ครอบน๊อตล้อหน้าด้านขวามีรอยชนบุบ
#
#
#
#
# ที่เกิดเหตุพบผู้บาดเจ็บเป็นชาย 1 รายทราบชื่อบดินทร์ สมจิตต์ อายุ 35 ปีอยู่บ้านเลขที่ 13 ซอยลาดพร้าววังหิน แขวงลาดพร้าว กรุงเทพ คนขับรถบิ๊กไบก์ ได้รับบาดเจ็บสภาพมีแผลถลอกตามร่างกายเสื้อผ้ามีรอยขาด เจ้าหน้าที่กู้ภัยช่วยปฐมพยาบาลเบื้องต้นก่อนรีบนำส่งโรงพยาบาลบางปลาม้า ให้แพทย์ตรวจรักษา
#
# จากการสอบสวนนายสิทธิโชค แซ่ฉินอายุ 24 ปีคนขับรถพ่วงให้การว่าก่อนเกิดเหตุได้ขับรถบรรทุกหินจากจังหวัดสุพรรณบุรี จะเอาไปลงที่จังหวัดนครปฐม ถึงที่เกิดเหตุมีรถพ่วงจอดอยู่เลนซ้ายแล้วมีรถบรรทุกน้ำมันขับออกมาเลนของตนและมีรถกระบะอยู่ด้านหน้า จังหวะนั้นรถกำลังจอแจ รถน้ำมันและกระบะเบรก ตนก็เบรคตามแต่เบรคไม่อยู่ตนก็ชนท้ายรถกระบะและรถของตนเสียการทรงตัวเป๋ออกเลนขวา เป็นจังหวะเดียวกับที่รถบิ๊กไบก์ขับมาพอดีรถบิ๊กไบก์หลบไม่ทันจึงชนเข้าที่ล้อหน้าด้านขวารถของตนจนเกิดอุบัติเหตุขึ้น
#
#
#
# ขณะเดียวกันช่วงเกิดเหตุมีพลเมืองดีได้ขับรถกระบะตามมากล้องหน้ารถกระบะของพลเมืองดีจับภาพขณะขบวนรถบิ๊กไบก์ ประมาณ 10 กว่าคันกำลังขับอยู่เลนกลางมีรถพ่วงขับอยู่เลนซ้ายจู่ๆรถพ่วงได้เบนหัวรถเข้าเลนขวารถบิ๊กไบก์หลบไม่ทันจึงชนเข้าที่ล้อหน้ารถพ่วงอย่างจังจนล้มกระเด็นไถลไปกับพื้นถนนก่อนจะเกิดไฟลุกไหม้ จังหวะนั้น 1 ในทีมรถบิ๊กไบก์ที่ขับตามหลังตั้งสติได้รีบเข้าช่วยเหลือดึงร่างคนเจ็บออกจากที่เกิดเหตุก่อนที่ไฟจะลุกไหม้ขึ้นอย่างรุนแรงทำให้นายบดินทร์ สมจิตต์ อายุ 35 ปี เจ้าของบิ๊กไบก์คันเกิดเหตุรอยตายจากการถูกย่างสดอย่างหวุดหวิดท่ามกลางเสียงร้องด้วยความตกใจของภรรยาเจ้าของรถกระบะที่มีกล้องวงจรปิดจับภาพขณะเกิดเหตุ
#
#
#
#
# จากการสอบสวนเบื้องต้นทราบว่าก่อนเกิดเหตุกลุ่มรถบิ๊กไบก์ได้จัดทริป ท่องเที่ยวเมืองสุพรรณบุรี โดยเริ่มจากการกราบขอพรเจ้าพ่อหลักเมืองสุพรรณบุรี บริเวณอุทยานมังกรสวรรค์ จากนั้นได้ไปเที่ยวชมเรือนขุนแผนที่วัดแค ก่อนจะไปเที่ยวชมหมู่บ้านอนุรักษ์ควายไทยที่ศรีประจันต์และกำลังเดินทางกลับบ้านพักที่กรุงเทพก่อนจะมาประสบอุบัติเหตุขึ้น เบื้องต้นพนักงานสอบสวน สภ.บางปลาม้า ยังไม่ได้แจ้งข้อกล่าวหาใครต้องรอสอบสวนสาเหตุของการเกิดอุบัติเหตุที่แท้จริงและรวบรวมพยานหลักฐานก่อนจะดำเนินคดีตามกฎหมายต่อไป' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn(

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl.metadata (2.6 kB)
# Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.9
# Note: you may need to restart the kernel to use updated packages.
